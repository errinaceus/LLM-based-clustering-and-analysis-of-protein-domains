# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import time
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
from Bio import SeqIO

# %%
df_c=pd.read_csv('Dm_T5_umap_gmm_clusters.csv')
df_b=pd.read_csv('Dm_ProtBERT_umap_gmm_clusters.csv')
df_a = pd.DataFrame()
df_a['x']=df_c['x']
df_a['y']=df_c['y']
df_a['color']=df_b['gmm']

# %%
plot=sns.relplot(
    x="x", y="y", hue="color", data=df_a, height=6,
);

# %%
plot.figure.savefig("DmC2H2_t5_umap_gmm_colored_byProtBERT.svg")

# %%
df_a['id']=df_c['id']
df_a.to_csv('DmC2H2_t5_umap_gmm_colored_byProtBERT_clusters.csv')
